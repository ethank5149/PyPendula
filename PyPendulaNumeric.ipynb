# %%
from pypendula import PyPendula

# %%
FPS = 120
ALPHA = 3
BETA = 2048

# %% [markdown]
# #### $n=1$

# %%
p1 = PyPendula(N=1, l=1, fps=FPS, alpha=ALPHA, beta=BETA)
p1.preview()
p1.simulate()
# Out:
# Solving Numeric Problem... Done!
# Setting Up Simulation... Done!
# Saving Animation: |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%

# %% [markdown]
# #### $n=2$

# %%
p2 = PyPendula(N=2, l=1/2., fps=FPS, alpha=ALPHA, beta=BETA)
p2.preview()
p2.simulate()
# Out:
# Solving Numeric Problem... Done!
# Setting Up Simulation... Done!
# Saving Animation: |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%

# %% [markdown]
# #### $n=3$

# %%
p3 = PyPendula(N=3, l=1/3., fps=FPS, alpha=ALPHA, beta=BETA)
p3.preview()
p3.simulate()
# Out:
# Solving Numeric Problem...
# Done!
# Setting Up Simulation... Done!
# Saving Animation: |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
